# %%
# load the dataset.
import pandas as pd
df = pd.read_csv('/Users/caihao/VSCode/AI-drug/all_companies.csv')
df.head()
# Out:
#        company_name                              category  \
# 0             3BIGS  Aggregate and synthesize information
# 1           Amplion  Aggregate and synthesize information
# 2      BioSymetrics  Aggregate and synthesize information
# 3  OneThree Biotech  Aggregate and synthesize information
# 4             Owkin  Aggregate and synthesize information
#
#                        website  \
# 0             http://3bigs.com
# 1      https://www.amplion.com
# 2  http://www.biosymetrics.com
# 3        https://onethree.bio/
# 4         http://www.owkin.com
#
#                                           uses_ai_to  \
# 0  Discover relationships between diseases, targe...
# 1  Synthesize biomedical knowledge and biomarker ...
# 2  Process raw phenotypic, imaging, drug, and gen...
# 3  Integrate and analyze data from over 30 types ...
# 4  Build intelligence from distributed datasets, ...
#
#                                allows_researchers_to  founded  \
# 0                Repurpose drugs for new indications     2017
# 1  Ensure an effective mix of biomarkers, establi...     2013
# 2  Integrate rapid analytics and machine learning...     2015
# 3  Generate new insights across the drug developm...     2018
# 4  Overcome the problem of data-sharing in health...     2016
#
#                              headquarters      city               state  \
# 0  Suwon, Ch'ungch'ong-namdo, South Korea     Suwon  Ch'ungch'ong-namdo
# 1             Bend, Oregon, United States      Bend              Oregon
# 2       New York, New York, United States  New York            New York
# 3       New York, New York, United States  New York            New York
# 4       New York, New York, United States  New York            New York
#
#          country   latitude   longitude  count funding_stage  funding_amount
# 0    South Korea  37.263332  127.028747      1           NaN             NaN
# 1  United States  44.058173 -121.315310      1             A             2.6
# 2  United States  40.712728  -74.006015     14           NaN             NaN
# 3  United States  40.712728  -74.006015     14          Seed             2.5
# 4  United States  40.712728  -74.006015     14             A            56.1

# %%
dataset = df[['company_name', 'category', 'uses_ai_to', 'allows_researchers_to']].copy()
dataset['text'] = dataset['uses_ai_to'] + ' ' + dataset['allows_researchers_to']
dataset.head()
# Out:
#        company_name                              category  \
# 0             3BIGS  Aggregate and synthesize information
# 1           Amplion  Aggregate and synthesize information
# 2      BioSymetrics  Aggregate and synthesize information
# 3  OneThree Biotech  Aggregate and synthesize information
# 4             Owkin  Aggregate and synthesize information
#
#                                           uses_ai_to  \
# 0  Discover relationships between diseases, targe...
# 1  Synthesize biomedical knowledge and biomarker ...
# 2  Process raw phenotypic, imaging, drug, and gen...
# 3  Integrate and analyze data from over 30 types ...
# 4  Build intelligence from distributed datasets, ...
#
#                                allows_researchers_to  \
# 0                Repurpose drugs for new indications
# 1  Ensure an effective mix of biomarkers, establi...
# 2  Integrate rapid analytics and machine learning...
# 3  Generate new insights across the drug developm...
# 4  Overcome the problem of data-sharing in health...
#
#                                                 text
# 0  Discover relationships between diseases, targe...
# 1  Synthesize biomedical knowledge and biomarker ...
# 2  Process raw phenotypic, imaging, drug, and gen...
# 3  Integrate and analyze data from over 30 types ...
# 4  Build intelligence from distributed datasets, ...

# %% [markdown]
# ## Fetch word count

# %%
#Fetch wordcount for each abstract
dataset['word_count_ai'] = dataset['uses_ai_to'].apply(lambda x: len(str(x).split(" ")))
dataset['word_count_research'] = dataset['allows_researchers_to'].apply(lambda x: len(str(x).split(" ")))
dataset['word_count'] = dataset['text'].apply(lambda x: len(str(x).split(" ")))
dataset.describe()
# Out:
#        word_count_ai  word_count_research  word_count
# count     230.000000           230.000000  230.000000
# mean       11.330435            12.547826   23.878261
# std         5.164071             5.285299    7.619382
# min         2.000000             4.000000    7.000000
# 25%         8.000000             9.000000   18.250000
# 50%        10.000000            11.500000   23.000000
# 75%        15.000000            15.000000   29.000000
# max        28.000000            28.000000   48.000000

# %% [markdown]
# ## Most common and uncommon words

# %%
#Identify common words
freq = pd.Series(' '.join(dataset['text']).split()).value_counts()[:50]
freq
# Out:
# and            342
# of             172
# for            112
# to             110
# data            99
# the             91
# in              86
# from            75
# drug            74
# a               69
# clinical        64
# with            61
# Analyze         55
# drugs           47
# new             47
# novel           47
# that            38
# Predict         32
# on              32
# diseases        29
# trials          29
# patients        28
# cancer          27
# disease         26
# by              25
# candidates      24
# targets         23
# discovery       23
# insights        22
# development     21
# Find            21
# Develop         21
# as              21
# compounds       21
# molecules       21
# molecular       20
# trial           19
# Generate        19
# identify        16
# patient         16
# biomedical      16
# Identify        16
# biological      16
# therapeutic     16
# at              15
# into            15
# design          15
# including       15
# Discover        15
# protein         15
# dtype: int64

# %%
#Identify uncommon words
infreq =  pd.Series(' '.join(dataset['text']).split()).value_counts()[-50:]
infreq
# Out:
# product             1
# stability,          1
# DNA-encoded         1
# extensive           1
# Engine"             1
# strong              1
# available           1
# CNS                 1
# adherence           1
# guides              1
# Mine                1
# shelved             1
# smart               1
# (with               1
# critical            1
# cross-reactivity    1
# selection,          1
# rigorous            1
# convolutional       1
# accuracy            1
# diseased            1
# ahead               1
# goal                1
# reactive            1
# engineered          1
# encephalopathy      1
# observation,        1
# libraries)          1
# time-to-market      1
# something           1
# at-risk             1
# recreates           1
# advance             1
# might               1
# likely              1
# aim                 1
# limited             1
# outcome             1
# (Details            1
# day                 1
# creative            1
# producing           1
# development,        1
# weed                1
# it's                1
# resistance          1
# process.            1
# pharmacology        1
# simultaneously      1
# metabolic           1
# dtype: int64

# %% [markdown]
# ## Text Preprocessing

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
stem = PorterStemmer()
word = "inversely"
print("stemming:",stem.stem(word))
print("lemmatization:", lem.lemmatize(word, "v"))
# Out:
# stemming: invers
# lemmatization: inversely

# %%
# Libraries for text preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
#nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer

# %%
##Creating a list of stop words and adding custom stopwords
stop_words = set(stopwords.words("english"))
##Creating a list of custom stopwords
##Creating a list of stop words and adding custom stopwords
stop_words = set(stopwords.words("english"))
##Creating a list of custom stopwords
new_words = ['and', 'of', 'data', 'from', 'analyze', 'to', 'in', 'the', 'a', 'for', 'with', 'that', 'on', 'insights', 'novel', 'by', 'as', 'new', 'find', 'datasets', 'biological', 'sources', 'generate', 'discovery', 'complex', 'find', 'other','and', 'of', 'for', 'to', 'the', 'in', 'new', 'with', 'novel', 'a', 'develop', 'that', 'development', 'data', 'from', 'on', 'by', 'find', 'more', 'as', 'at', 'improve', 'based']
stop_words = stop_words.union(new_words)

# %%
def preprocessing(dataset):
    corpus = []
    for i in range(0, len(dataset)):
        #Remove punctuations
        text = re.sub('[^a-zA-Z]', ' ', dataset['text'][i])
        
        #Convert to lowercase
        text = text.lower()
        
        #remove tags
        text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
        
        # remove special characters and digits
        text=re.sub("(\\d|\\W)+"," ",text)
        
        ##Convert to list from string
        text = text.split()
        
        ##Stemming
        ps=PorterStemmer()
        #Lemmatisation
        lem = WordNetLemmatizer()
        text = [lem.lemmatize(word) for word in text if not word in  
                stop_words] 
        text = " ".join(text)
        corpus.append(text)
    return corpus

corpus = preprocessing(dataset=dataset)

# %%
corpus[:20]
# Out:
# ['discover relationship disease target drug repurpose drug indication',
#  'synthesize biomedical knowledge biomarker expertise guide biomarker strategic planning ensure effective mix biomarkers establish differentiation recruit right patient identify best companion diagnostic opportunity',
#  'process raw phenotypic imaging drug genomic set integrate rapid analytics machine learning capability existing business process care enhance discovery gain insight business enable fast driven decision',
#  'integrate type chemical clinical across drug pipeline including target mechanism action',
#  'build intelligence distributed including privacy safe transfer federated learning overcome problem sharing healthcare automate diagnostics predict treatment outcome optimize clinical trial',
#  'identify unique neural signature alzheimer disease electroencephalography monitor response alzheimer disease treatment including clinical trial',
#  'pathology slide model incorporate diagnosis world foremost cancer expert accelerate cancer biomarker get disease decade pathology',
#  'model mature cardiac tissue engineered induced pluripotent stem cell predict physiological effect different drug heart condition',
#  'iterate small molecule candidate optimal property target design treatment disease including cancer bacterial infection muscular dystrophy',
#  'rna patient identify biomarkers drug target accelerate rna therapeutic',
#  'undiscovered molecule encoded environmental microbial dna address undruggable target structurally diverse molecule drug like property',
#  'ideate optimize drug candidate evaluate chemical compound silico ahead synthesis assay',
#  'estimate risk clinical trial interpret multitude factor contribute risk de risk drug clinical trial stage',
#  'match cancer patient active clinical trial facilitate oncology clinical trial enrollment',
#  'visually confirm medication ingestion via smartphone medication adherence clinical trial',
#  'medical pharmacy claim understand treatment work best patient time',
#  'create curated database analysis published scientific literature extract structured knowledge power drug application',
#  'read scientific article extract causal association search cause effect relationship gather evidence biomedical entity interact',
#  'curate combination human expertise million scientific paper thousand publication stay date scientific publication patent',
#  'uncover genetic gain access secure dna incentivising protecting patient confidentiality']

# %% [markdown]
# ## Word Cloud

# %%
# Word cloud for entire corpus.
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
fig, (ax1) = plt.subplots(1, 1, figsize=(6, 4))
ax1.imshow(wordcloud)
ax1.axis('off')
plt.show()

# %%
# Word cloud for different categories.
phases = ['Aggregate and synthesize information', 'Understand mechanisms of disease', 'Establish biomarkers', 'Generate data and models', 'Repurpose existing drugs', 'Generate novel drug candidates', 'Validate and optimize drug candidates', 'Design drugs', 'Design preclinical experiments', 'Run preclinical experiments', 'Design clinical trials', 'Recruit for clinical trials', 'Optimize clinical trials', 'Publish data', 'Analyze real world evidence']
corpuses = []
for phase in phases:
    dataset_p = dataset.loc[dataset.category==phase].copy().reset_index(drop=True)
    corpus_p = preprocessing(dataset_p)
    corpuses.append(corpus_p)

# %%
fig, [[ax1, ax2, ax3],
      [ax4, ax5, ax6],
      [ax7, ax8, ax9],
      [ax10, ax11, ax12],
      [ax13, ax14, ax15]] = plt.subplots(5, 3, figsize=(15, 15))
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15]
for i, corpus in enumerate(corpuses):
    phase = phases[i]
    ax = axes[i]
    wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
    ax.imshow(wordcloud)
    ax.axis('off')
    ax.set_title(phase)
plt.show()
